# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshunayak05/NLP/blob/main/Priyanshu_Nayak_39_(NLP_Practical_exam).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
#  Matches valid email patterns

text = "Contact us at support@example.com or info@my-site.org"
matches = re.findall(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", text)
print(matches)
# Out:
# ['support@example.com', 'info@my-site.org']

# %%
# www\.\S+ → Matches URLs starting with www..

text = "Visit http://example.com or https://secure.site.org or www.test.com"
matches = re.findall(r"https?://\S+|www\.\S+", text)
print(matches)
# Out:
# ['http://example.com', 'https://secure.site.org', 'www.test.com']

# %%
#  extract phone number
 pattern = re.compile(r'^(?:\+91|91)?[ -]?[6-9]\d{9}$',text)

# %%
text = "Loving #Python, #MachineLearning and #AI in 2025! #100DaysOfCode"

hashtags = re.findall(r'#\w+', text)
print(hashtags)
# Out:
# ['#Python', '#MachineLearning', '#AI', '#100DaysOfCode']
